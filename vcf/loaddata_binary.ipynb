# %%
# Load data
import pickle as pkl
import pandas as pd
import ast
import numpy as np
from matplotlib import pyplot as plt
# Load list of data
dfbin = pd.read_csv('Matrix.csv')

mixnames = dfbin.columns[1:].values
molecules = dfbin['Unnamed: 0'].values
x = dfbin.values[0:,1:].astype('float').T

fig, ax = plt.subplots(1,1,figsize = (15,5), sharey = 'row')
im = ax.imshow(x, interpolation = 'none')
ax.set_xlabel('molecules'); ax.set_ylabel('mixtures')
plt.show()

# %%
print(len(mixnames))
x.shape
# Out:
# 1384
# (1384, 8730)

# %%
mixnames == 'BARRAMUNDI'
np.sum(dfbin['BARRAMUNDI_(lates_calcarifer)_(grilled,_farmed)_5582.html'] != dfbin['BARRAMUNDI_(lates_calcarifer)_(wild,_grilled)_5583.html'])
# Out:
# 2
